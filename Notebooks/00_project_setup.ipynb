# %%
base_path = "/Volumes/retailanalytics/default/retail_volume"

folders = [
    "bronze/products",
    "bronze/customers",
    "bronze/orders",
    "bronze/exchange_rates",

    "silver/products",
    "silver/customers",
    "silver/orders",
    "silver/exchange_rates",

    "gold/dim_customer",
    "gold/dim_product",
    "gold/fact_sales",

    "audit",
    "reject",
    "metadata"
]

for folder in folders:
    dbutils.fs.mkdirs(f"{base_path}/{folder}")

print("Project folders created successfully")
# Out:
# Project folders created successfully

# %%
display(
    dbutils.fs.ls(
        "/Volumes/retailanalytics/default/retail_volume"
    )
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
